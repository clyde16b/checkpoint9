# %% [markdown]
# # Apriori

# %% [raw]
# Mimportant les bibliotheque Pandas, Numpy,mlxtend

# %%
import mlxtend
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.preprocessing import TransactionEncoder

# %% [raw]
# Créeons une liste dataset

# %%
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],

        ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],

        ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],

        ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],

      ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %% [raw]
# encodons la liste dataset

# %%
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)    
df=pd.DataFrame(te_ary, columns=te.columns_) 
df
# Out:
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False

# %%
from mlxtend.frequent_patterns import apriori
apriori(df, min_support=0.01)
# Out:
#      support            itemsets
# 0        0.4                 (0)
# 1        0.4                 (1)
# 2        0.6                 (2)
# 3        0.4                 (3)
# 4        0.2                 (4)
# ..       ...                 ...
# 146      0.2     (1, 2, 3, 4, 7)
# 147      0.2     (1, 5, 7, 8, 9)
# 148      0.2    (2, 5, 7, 9, 10)
# 149      0.2   (2, 5, 9, 10, 11)
# 150      0.2  (0, 1, 2, 3, 4, 7)
#
# [151 rows x 2 columns]

# %%
frequent_itemsets1=apriori(df, min_support=0.5, use_colnames=True)
frequent_itemsets1
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Scarf, Pants)
# 5      0.6  (Skirt, Pants)

# %%
frequent_itemsets1.plot(kind='bar',figsize=(12,8),title="Frequent Items")
# Out:
# <AxesSubplot:title={'center':'Frequent Items'}>

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets1,metric="confidence",min_threshold=.25)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 1     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 2     (Skirt)     (Pants)                 0.6                 0.8      0.6
# 3     (Pants)     (Skirt)                 0.8                 0.6      0.6
#
#    confidence    lift  leverage  conviction
# 0        0.75  0.9375     -0.04         0.8
# 1        0.75  0.9375     -0.04         0.8
# 2        1.00  1.2500      0.12         inf
# 3        0.75  1.2500      0.12         1.6

# %%
association_rules(frequent_itemsets1,metric="lift",min_threshold=.2)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 1     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 2     (Skirt)     (Pants)                 0.6                 0.8      0.6
# 3     (Pants)     (Skirt)                 0.8                 0.6      0.6
#
#    confidence    lift  leverage  conviction
# 0        0.75  0.9375     -0.04         0.8
# 1        0.75  0.9375     -0.04         0.8
# 2        1.00  1.2500      0.12         inf
# 3        0.75  1.2500      0.12         1.6

# %% [raw]
# important la dataset_2 avec pandas puis on la transforme en liste

# %%
dataset_2=pd.read_csv("Market_Basket_Optimisation.csv", header=None)
dataset_2=dataset_2.T.apply(lambda x: x.dropna().tolist()).tolist()
dataset_2
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries'],
#  ['eggs', 'pet food'],
#  ['cookies'],
#  ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon'],
#  ['mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
# ...

# %%
te=TransactionEncoder()
te_ary=te.fit(dataset_2).transform(dataset_2)    
df=pd.DataFrame(te_ary, columns=te.columns_)  
df
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
# ...

# %%
apriori(df, min_support=0.01)
frequent_itemsets=apriori(df, min_support=0.01, use_colnames=True)
frequent_itemsets
# Out:
#       support                                 itemsets
# 0    0.020397                                (almonds)
# 1    0.033329                                (avocado)
# 2    0.010799                         (barbecue sauce)
# 3    0.014265                              (black tea)
# 4    0.011465                             (body spray)
# ..        ...                                      ...
# 252  0.011065       (ground beef, milk, mineral water)
# 253  0.017064  (ground beef, spaghetti, mineral water)
# 254  0.015731         (milk, spaghetti, mineral water)
# 255  0.010265    (olive oil, spaghetti, mineral water)
# 256  0.011465     (pancakes, mineral water, spaghetti)
#
# [257 rows x 2 columns]

# %%
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.4)
# Out:
#                        antecedents      consequents  antecedent support  \
# 0                    (ground beef)  (mineral water)            0.098254
# 1                      (olive oil)  (mineral water)            0.065858
# 2                         (salmon)  (mineral water)            0.042528
# 3                           (soup)  (mineral water)            0.050527
# 4                (eggs, chocolate)  (mineral water)            0.033196
# 5         (ground beef, chocolate)  (mineral water)            0.023064
# 6                (chocolate, milk)  (mineral water)            0.032129
# 7           (chocolate, spaghetti)  (mineral water)            0.039195
# 8              (eggs, ground beef)  (mineral water)            0.019997
# 9                     (eggs, milk)  (mineral water)            0.030796
# 10       (frozen vegetables, milk)  (mineral water)            0.023597
# 11  (frozen vegetables, spaghetti)  (mineral water)            0.027863
# ...

# %%
a=association_rules(frequent_itemsets,metric="lift",min_threshold=2)

# %% [raw]
# on a sur le dernier tableau le lifit>1 qui veux dire ces produit sont fortement corélé entre eux par exemple:
# celui qui achete "frozen vegetables" a plus de chance d'acheté "shrimp" avec un lift de 2.446574 largement superieur a 1
